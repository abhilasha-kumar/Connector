# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import torch
from scipy.spatial.distance import cosine

# %% [markdown]
# ## Loading CSV File

# %%
df = pd.read_csv("glove_embeddings.csv")

# %%
df.head()
# Out:
#           a  aardvark    abacus   abandon     abbey  abbreviation  abdicate  \
# 0  0.053397 -0.008875 -0.013335 -0.006122  0.019756      0.030545 -0.069542
# 1 -0.004251  0.002891  0.047071 -0.083403 -0.078187      0.082258  0.023200
# 2 -0.110815 -0.045953 -0.011582 -0.048378 -0.039875     -0.107963  0.015946
# 3  0.069536  0.047428 -0.018891  0.090270  0.012006     -0.053957  0.053257
# 4 -0.041571 -0.039259 -0.001189 -0.010410  0.030436     -0.064063  0.102261
#
#     abdomen    abduct  abduction  ...    zipper       zit    zodiac    zombie  \
# 0 -0.056377  0.003284   0.003534  ... -0.064620  0.029034 -0.002440 -0.044165
# 1  0.045625  0.018514   0.037448  ...  0.126727 -0.127292  0.033536 -0.010979
# 2 -0.011218 -0.008692  -0.120792  ... -0.024138 -0.056325 -0.072633  0.080010
# 3 -0.036753 -0.001521  -0.029523  ... -0.000864 -0.018538  0.002866  0.018774
# 4 -0.058631  0.110090   0.105033  ... -0.022811  0.056904  0.045423  0.060763
#
#     zombies      zone       zoo      zoom  zucchini  bandanna
# 0  0.098675 -0.044571  0.005611  0.067518 -0.145417 -0.039534
# 1  0.002700  0.086612 -0.035475  0.083952  0.076169  0.014235
# 2 -0.070075 -0.097581 -0.072470 -0.013439  0.009109 -0.027750
# 3  0.049107  0.105542  0.024093 -0.006343  0.027500 -0.041883
# 4 -0.004891 -0.014069 -0.027471 -0.018964 -0.077316  0.063027
#
# [5 rows x 12218 columns]

# %% [markdown]
# ## Task 1: Create a function to compute cosine similarity between any two word vectors:

# %%
def cosine_similarity(word1, word2):
    return 1 - cosine(torch.from_numpy(np.array(df[word1])),torch.from_numpy(np.array(df[word2])))

# %%
cosine_similarity("skull", "brain")
# Out:
# 0.44759619387211047

# %% [markdown]
# ## Task 2: Create a function to find the word closest to another word in the vocab using cosines:

# %%
def find_closest(word):
  sims = [cosine_similarity(word,x) for x in df.columns]
  y = np.array(sims)
  y_sorted = np.argsort(-y) ## gives sorted indices
  top5_indices = y_sorted[:5]
  w1 = [df.columns[i] for i in top5_indices]
  return w1

# %%
print(find_closest('brain'))
print(find_closest('cat'))
print(find_closest('apple'))
print(find_closest('exam'))

print(find_closest('brain'))
print(find_closest('cat'))
print(find_closest('apple'))
print(find_closest('exam'))
# Out:
# ['brain', 'cerebral', 'tumor', 'spinal', 'tissue']
# ['cat', 'dog', 'pet', 'rabbit', 'pig']
# ['apple', 'applesauce', 'pear', 'apple pie', 'cherry']
# ['exam', 'examination', 'exams', 'admission', 'graduation']
# ['brain', 'cerebral', 'tumor', 'spinal', 'tissue']
# ['cat', 'dog', 'pet', 'rabbit', 'pig']
# ['apple', 'applesauce', 'pear', 'apple pie', 'cherry']
# ['exam', 'examination', 'exams', 'admission', 'graduation']

# %% [markdown]
# ## Task 3: Create a function to compute the average vector of any two vectors:

# %%
def avg_vector(word1, word2):
    return torch.divide(torch.add(torch.from_numpy(np.array(df[word1])),torch.from_numpy(np.array(df[word2]))),2)

# %%
print(avg_vector("brain","skull").size())
# Out:
# torch.Size([300])

# %% [markdown]
# ## Task 4: Create a function to find the word in the vocab closest to an average vector for each wordpair:

# %%
def closest_word(word1, word2):
    avg_vector_tensor = avg_vector(word1, word2)
    sims_cosine = [1 - cosine(avg_vector_tensor,torch.from_numpy(np.array(df[x]))) for x in df.columns]
    y = np.array(sims_cosine)
    y_sorted = np.argsort(-y) ## gives sorted indices
    top5_indices = y_sorted[:5]
    w1 = [df.columns[i] for i in top5_indices]
    return w1

# %%
print(closest_word("lion","tiger"))
# Out:
# ['tiger', 'lion', 'leopard', 'elephant', 'wolf']

# %% [markdown]
# ## Testing function on a csv file with pair of words:

# %%
df_word_pair = pd.read_csv("connector_wordpairs_boards.csv")

# %%
df_word_pair.head(5)
# Out:
#      Word1     Word2 Experiment        boardnames
# 0     void     couch         E1   e1_board1_words
# 1   giggle  abnormal         E1   e1_board1_words
# 2     exam   algebra         E1   e1_board1_words
# 3      tea      bean         E1  e1_board10_words
# 4  tourist    comedy         E1  e1_board10_words

# %%
len(df_word_pair)
# Out:
# 60

# %%
similarity = []
for index, row in df_word_pair.iterrows():
    word1 = row["Word1"]
    word2 = row["Word2"]
    similarity.append(closest_word(word1, word2)[2:])

# %%
df_word_pair["top 3 similar words"] = similarity

# %% [markdown]
# ## Results

# %%
df_word_pair.head(60)
# Out:
#           Word1      Word2 Experiment        boardnames  \
# 0          void      couch         E1   e1_board1_words
# 1        giggle   abnormal         E1   e1_board1_words
# 2          exam    algebra         E1   e1_board1_words
# 3           tea       bean         E1  e1_board10_words
# 4       tourist     comedy         E1  e1_board10_words
# 5      pendulum       dusk         E1  e1_board10_words
# 6     beginning      brake         E1   e1_board2_words
# 7         birds   aircraft         E1   e1_board2_words
# 8        school       stop         E1   e1_board2_words
# 9        circle      dance         E1   e1_board3_words
# 10       famine    calorie         E1   e1_board3_words
# 11      hundred    economy         E1   e1_board3_words
# 12       corpse      fight         E1   e1_board4_words
# 13        graph       copy         E1   e1_board4_words
# 14      kitchen        egg         E1   e1_board4_words
# 15         near  astronaut         E1   e1_board5_words
# 16     homeless  apartment         E1   e1_board5_words
# 17        onion  cigarette         E1   e1_board5_words
# 18        pants     collar         E1   e1_board6_words
# 19   definition     assist         E1   e1_board6_words
# 20          war      quiet         E1   e1_board6_words
# 21         flat      alike         E1   e1_board7_words
# 22      perjury   adultery         E1   e1_board7_words
# 23        heavy    feather         E1   e1_board7_words
# 24       breeze     bubble         E1   e1_board8_words
# 25          bad    actress         E1   e1_board8_words
# 26  communicate    cooking         E1   e1_board8_words
# 27          bat     bounce         E1   e1_board9_words
# 28         toes    Dracula         E1   e1_board9_words
# 29        lunch     almond         E1   e1_board9_words
# 30         cave     knight         E2   e2_board1_words
# 31        quick       glow         E2   e2_board1_words
# 32         tree        oak         E2   e2_board1_words
# 33       garage       bone         E2  e2_board10_words
# 34         feet     chapel         E2  e2_board10_words
# 35        chair      table         E2  e2_board10_words
# 36        stern       wind         E2   e2_board2_words
# 37          sun       bowl         E2   e2_board2_words
# 38         gold     silver         E2   e2_board2_words
# 39         holy       kind         E2   e2_board3_words
# 40        teeth       gums         E2   e2_board3_words
# 41         rude     regret         E2   e2_board3_words
# 42        dream        bet         E2   e2_board4_words
# 43         jump       leap         E2   e2_board4_words
# 44       travel      ankle         E2   e2_board4_words
# 45        snake        ash         E2   e2_board5_words
# 46         hand      birth         E2   e2_board5_words
# 47         lion      tiger         E2   e2_board5_words
# 48          elm       rock         E2   e2_board6_words
# 49        crust       boot         E2   e2_board6_words
# 50          sit      stand         E2   e2_board6_words
# 51         east      short         E2   e2_board7_words
# 52          old        new         E2   e2_board7_words
# 53        glass       cage         E2   e2_board7_words
# 54        giant     subtle         E2   e2_board8_words
# 55         army       drum         E2   e2_board8_words
# 56        happy        sad         E2   e2_board8_words
# 57        weird     trauma         E2   e2_board9_words
# 58        olive       real         E2   e2_board9_words
# 59       candle       wick         E2   e2_board9_words
#
#                       top 3 similar words
# 0                       [fill, sit, sofa]
# 1         [laughter, hysterical, symptom]
# 2       [mathematics, exams, examination]
# 3               [coffee, rice, vegetable]
# 4            [popular, movie, attraction]
# 5                 [dawn, sunset, sunrise]
# 6                     [end, start, early]
# 7                 [fly, airplane, flight]
# 8                   [go, continue, start]
# 9                [dancing, dancer, music]
# 10             [starvation, food, hunger]
# 11            [thousand, dozen, economic]
# 12                    [dead, kill, alive]
# 13              [print, instance, number]
# 14                      [cook, eat, food]
# 15             [nearby, vicinity, locate]
# 16              [housing, house, elderly]
# 17              [tobacco, garlic, potato]
# 18              [trousers, shirt, jacket]
# 19                    [define, aid, need]
# 20                 [conflict, calm, even]
# 21               [generally, quite, even]
# 22              [felony, treason, guilty]
# 23                    [tail, thick, hair]
# 24              [cool, bubble wrap, blow]
# 25                 [actor, bad guy, good]
# 26           [learn, cook, communication]
# 27                      [ball, hit, toss]
# 28  [knees and toes, Frankenstein, knees]
# 29              [meal, breakfast, peanut]
# 30                 [castle, cavern, tomb]
# 31                  [bright, light, slow]
# 32               [pine, palm tree, grove]
# 33                 [basement, skull, hip]
# 34               [church, cemetery, hall]
# 35        [sit, rocking chair, committee]
# 36                     [bow, blow, storm]
# 37                [ball, sky, Super Bowl]
# 38                [bronze, medal, copper]
# 39                  [thing, sort, always]
# 40                 [candles, tied, knees]
# 41             [apologize, remark, angry]
# 42                [chance, want, nothing]
# 43                 [jumping, throw, grab]
# 44                      [knee, trip, leg]
# 45                   [tree, sand, lizard]
# 46                  [mother, whose, upon]
# 47              [leopard, elephant, wolf]
# 48                       [tree, pop, oak]
# 49                  [shoe, belt, leather]
# 50                 [it, standing, beside]
# 51                   [west, south, north]
# 52             [original, still, another]
# 53      [steel, magnifying glass, inside]
# 54             [kind, resemble, creature]
# 55                 [troops, corps, force]
# 56             [really, lonely, everyone]
# 57           [bizarre, horrific, strange]
# 58          [actually, real estate, TRUE]
# 59              [lamp, incense, kerosene]

# %%
df_word_pair.to_csv("word_pair_results(Glove).csv")
