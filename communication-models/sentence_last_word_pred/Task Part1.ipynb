# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import happytransformer
from happytransformer import HappyWordPrediction

# %% [markdown]
# ## Loading the dataset using Pandas

# %%
responses_dataset = pd.read_excel("staub_data_original.xlsx")

# %% [markdown]
# ## Creating DataFrame

# %%
df = pd.DataFrame(responses_dataset)

# %%
df
# Out:
#        ItemNo      X ExperimentName  Subject  Session  DataFile.Basename  \
# 0           1      4   new.cloze.1x        6        1   new.cloze.1x-6-1
# 1           1      6   new.cloze.1x       11        1  new.cloze.1x-11-1
# 2           1      7   new.cloze.1x       12        1  new.cloze.1x-12-1
# 3           1      8   new.cloze.1x       14        1  new.cloze.1x-14-1
# 4           1      9   new.cloze.1x       16        1  new.cloze.1x-16-1
# ...       ...    ...            ...      ...      ...                ...
# 12040     338  13515   new.cloze.1x       19        1  new.cloze.1x-19-1
# 12041     338  13516   new.cloze.1x       29        1  new.cloze.1x-29-1
# 12042     338  13518   new.cloze.1x       36        1  new.cloze.1x-36-1
# 12043     338  13519   new.cloze.1x       25        1  new.cloze.1x-25-1
# 12044     338  13520   new.cloze.1x       33        1  new.cloze.1x-33-1
#
#        Block  List1  List1.Sample  Response.RESP  ...  Max.Ampl.Mean  cloze  \
# 0         28      1            18              6  ...       0.211670  0.025
# 1        129      1           119              6  ...       0.060379  0.625
# 2        335      1           325              6  ...       0.999970  0.625
# 3        166      1           156              6  ...       0.040527  0.625
# 4        272      1           262              6  ...       0.084763  0.625
# ...      ...    ...           ...            ...  ...            ...    ...
# 12040     47    338            37              6  ...       0.716260  0.050
# 12041    295    338           285              6  ...       0.024124  0.050
# 12042    347    338           337              6  ...       0.999970  0.050
# 12043    243    338           233              6  ...       0.076462  0.025
# 12044    277    338           267              6  ...       0.045486  0.025
#
#       max.cloze ClozeResp response.freq cloze.bin count.responses cloze.adj  \
# 0         0.625      game             1         0              37  0.027027
# 1         0.625      game            25         0              37  0.675676
# 2         0.625      game            25         0              37  0.675676
# 3         0.625      game            25         0              37  0.675676
# 4         0.625      game            25         0              37  0.675676
# ...         ...       ...           ...       ...             ...       ...
# 12040     0.225      help             2         0              40  0.050000
# 12041     0.225      help             2         0              40  0.050000
# 12042     0.225      help             2         0              40  0.050000
# 12043     0.225      help             1         0              40  0.025000
# 12044     0.225      help             1         0              40  0.025000
#
#       max.cloze.adj                        Sentence
# 0          0.675676  The ailing team forfeited the
# 1          0.675676  The ailing team forfeited the
# 2          0.675676  The ailing team forfeited the
# 3          0.675676  The ailing team forfeited the
# 4          0.675676  The ailing team forfeited the
# ...             ...                             ...
# 12040      0.225000   The young student needed the
# 12041      0.225000   The young student needed the
# 12042      0.225000   The young student needed the
# 12043      0.225000   The young student needed the
# 12044      0.225000   The young student needed the
#
# [12045 rows x 34 columns]

# %% [markdown]
# ## Creating the Masked Questions Numpy Array

# %%
questions_vector = np.array(df["Sentence"])

# %%
masked_questions_vector = np.array([[i+"[MASK]"] for i in df["Sentence"]])

# %%
masked_questions_vector.shape
# Out:
# (12045, 1)

# %%
masked_questions_vector[0]
# Out:
# array(['The ailing team forfeited the [MASK]'], dtype='<U47')

# %%
s = masked_questions_vector[0]

# %% [markdown]
# ## Using Pretrained BERT to predict last word of Sentence

# %%
happy_wp = HappyWordPrediction()
# Out:
# 10/25/2021 23:47:15 - INFO - happytransformer.happy_transformer -   Using model: cuda

# %%
s[0]
# Out:
# 'The ailing team forfeited the [MASK]'

# %% [markdown]
# ## Experimenting by returning top 10 words predicted

# %%
result = happy_wp.predict_mask(s[0],top_k = 10)

# %%
result
# Out:
# [WordPredictionResult(token='title', score=0.2217867225408554),
#  WordPredictionResult(token='championship', score=0.13578149676322937),
#  WordPredictionResult(token='trophy', score=0.11505868285894394),
#  WordPredictionResult(token='tournament', score=0.09288104623556137),
#  WordPredictionResult(token='match', score=0.06332535296678543),
#  WordPredictionResult(token='cup', score=0.038533806800842285),
#  WordPredictionResult(token='.', score=0.03294019773602486),
#  WordPredictionResult(token='game', score=0.030385807156562805),
#  WordPredictionResult(token='playoff', score=0.019028015434741974),
#  WordPredictionResult(token='final', score=0.017535381019115448)]

# %% [markdown]
# ### Printing predicted token

# %%
result[0].token
# Out:
# 'title'

# %% [markdown]
# ### Printing Predited score

# %%
result[0].score
# Out:
# 0.2217867225408554

# %% [markdown]
# ## Helper Function to get token for every masked sentence in the numpy array

# %%
def get_token(sentence):
    result = happy_wp.predict_mask(sentence)
    return result[0].token

# %% [markdown]
# ## Running Loop over Numpy Array sentences to get last word predicted via BERT

# %%
predictions = []
pred_tokens = []
for i in range(df.shape[0]):
    token = get_token(masked_questions_vector[i][0])
    pred_tokens.append([token])
    predictions.append([questions_vector[i] + token])
# Out:
# C:\Users\ajinkya2\anaconda3\envs\deeplearning\lib\site-packages\transformers\pipelines\base.py:899: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %% [markdown]
# ## Converting List of predicted tokens and predicted sentences to Pandas DataFrame to store as a CSV file

# %%
predictions_df = pd.DataFrame(predictions, columns = ["Predicted Sentence"])

# %%
tokens_df = pd.DataFrame(pred_tokens, columns = ["Predicted Tokens"])

# %%
predictions_df.shape
# Out:
# (12045, 1)

# %%
tokens_df.shape
# Out:
# (12045, 1)

# %%
predictions_df.to_csv("predictions_df.csv",index = False)

# %%
tokens_df.to_csv("tokens_df.csv",index = False)

# %% [markdown]
# ## Comparing performance of BERT to Human Responses by taking ratio of total correct predictions

# %%
people_responses = df["Resp"]

# %%
response_df = pd.DataFrame(people_responses)

# %%
pred_responses_df = pd.concat([response_df, tokens_df],axis = 1)

# %% [markdown]
# ### People Responses DataFrame

# %%
pred_responses_df
# Out:
#           Resp Predicted Tokens
# 0        fight            title
# 1         game            title
# 2         game            title
# 3         game            title
# 4         game            title
# ...        ...              ...
# 12040    paper                .
# 12041    paper                .
# 12042   pencil                .
# 12043  proctor                .
# 12044     time                .
#
# [12045 rows x 2 columns]

# %% [markdown]
# ### Now we match every word from the predicted frame and people responses frame return True if matched and return False if not matched.

# %%
pred_responses_df['isin'] =pred_responses_df.apply(lambda row: row['Resp'] in row['Predicted Tokens'],axis=1)

# %%
pred_responses_df
# Out:
#           Resp Predicted Tokens   isin
# 0        fight            title  False
# 1         game            title  False
# 2         game            title  False
# 3         game            title  False
# 4         game            title  False
# ...        ...              ...    ...
# 12040    paper                .  False
# 12041    paper                .  False
# 12042   pencil                .  False
# 12043  proctor                .  False
# 12044     time                .  False
#
# [12045 rows x 3 columns]

# %% [markdown]
# ### Next we take sum of True responses to get total correct predictions

# %%
pred_responses_df["isin"].sum()
# Out:
# 1130

# %% [markdown]
# We got 1130 correct predictions out of 12045.

# %% [markdown]
# ## Score Percent

# %%
score = (pred_responses_df["isin"].sum() / df.shape[0])*100
print(f"{score}%")
# Out:
# 9.38148609381486%

# %% [markdown]
# ## Using Pandas Frame Concatenation by to Analyze performance of BERT

# %%
pred_responses_df_qs = pd.concat([pred_responses_df,df["Sentence"]],axis = 1)

# %%
pred_responses_df_qs[60:120]
# Out:
#            Resp Predicted Tokens   isin  \
# 60      picture                .  False
# 61      picture                .  False
# 62      picture                .  False
# 63      picture                .  False
# 64      picture                .  False
# 65      picture                .  False
# 66      picture                .  False
# 67      picture                .  False
# 68         shot                .  False
# 69         shot                .  False
# 70   atmosphere             moon  False
# 71        earth             moon  False
# 72        earth             moon  False
# 73        earth             moon  False
# 74        earth             moon  False
# 75        earth             moon  False
# 76        earth             moon  False
# 77        earth             moon  False
# 78       galaxy             moon  False
# 79        globe             moon  False
# 80         moon             moon   True
# 81         moon             moon   True
# 82         moon             moon   True
# 83         moon             moon   True
# 84         moon             moon   True
# 85         moon             moon   True
# 86         moon             moon   True
# 87         moon             moon   True
# 88         moon             moon   True
# 89         moon             moon   True
# 90         moon             moon   True
# 91       planet             moon  False
# 92       rocket             moon  False
# 93         ship             moon  False
# 94        space             moon  False
# 95     universe             moon  False
# 96        world             moon  False
# 97        world             moon  False
# 98         baby           abbess  False
# 99          boy           abbess  False
# 100         boy           abbess  False
# 101         boy           abbess  False
# 102         boy           abbess  False
# 103       child           abbess  False
# 104       child           abbess  False
# 105       child           abbess  False
# 106       child           abbess  False
# 107       child           abbess  False
# 108       child           abbess  False
# 109       child           abbess  False
# 110       child           abbess  False
# 111       child           abbess  False
# 112       child           abbess  False
# 113       child           abbess  False
# 114       child           abbess  False
# 115       child           abbess  False
# 116       child           abbess  False
# 117       child           abbess  False
# 118       child           abbess  False
# 119       child           abbess  False
#
#                                    Sentence
# 60   The amateur photographer snapped some
# 61   The amateur photographer snapped some
# 62   The amateur photographer snapped some
# 63   The amateur photographer snapped some
# 64   The amateur photographer snapped some
# 65   The amateur photographer snapped some
# 66   The amateur photographer snapped some
# 67   The amateur photographer snapped some
# 68   The amateur photographer snapped some
# 69   The amateur photographer snapped some
# 70       The amazing astronaut orbited the
# 71       The amazing astronaut orbited the
# 72       The amazing astronaut orbited the
# 73       The amazing astronaut orbited the
# 74       The amazing astronaut orbited the
# 75       The amazing astronaut orbited the
# 76       The amazing astronaut orbited the
# 77       The amazing astronaut orbited the
# 78       The amazing astronaut orbited the
# 79       The amazing astronaut orbited the
# 80       The amazing astronaut orbited the
# 81       The amazing astronaut orbited the
# 82       The amazing astronaut orbited the
# 83       The amazing astronaut orbited the
# 84       The amazing astronaut orbited the
# 85       The amazing astronaut orbited the
# 86       The amazing astronaut orbited the
# 87       The amazing astronaut orbited the
# 88       The amazing astronaut orbited the
# 89       The amazing astronaut orbited the
# 90       The amazing astronaut orbited the
# 91       The amazing astronaut orbited the
# 92       The amazing astronaut orbited the
# 93       The amazing astronaut orbited the
# 94       The amazing astronaut orbited the
# 95       The amazing astronaut orbited the
# 96       The amazing astronaut orbited the
# 97       The amazing astronaut orbited the
# 98            The angry mother scolded the
# 99            The angry mother scolded the
# 100           The angry mother scolded the
# 101           The angry mother scolded the
# 102           The angry mother scolded the
# 103           The angry mother scolded the
# 104           The angry mother scolded the
# 105           The angry mother scolded the
# 106           The angry mother scolded the
# 107           The angry mother scolded the
# 108           The angry mother scolded the
# 109           The angry mother scolded the
# 110           The angry mother scolded the
# 111           The angry mother scolded the
# 112           The angry mother scolded the
# 113           The angry mother scolded the
# 114           The angry mother scolded the
# 115           The angry mother scolded the
# 116           The angry mother scolded the
# 117           The angry mother scolded the
# 118           The angry mother scolded the
# 119           The angry mother scolded the

# %% [markdown]
# ## Analysis Using GroupBy

# %%
iterator = pred_responses_df_qs.groupby(["Sentence"])

# %%
for name, group in iterator:
    print(name)
    print(group)
    print("\n")
# Out:
# The TV commercial promoted the
#                 Resp Predicted Tokens   isin                         Sentence
# 11483             ad             song  False  The TV commercial promoted the
# 11484             ad             song  False  The TV commercial promoted the
# 11485             ad             song  False  The TV commercial promoted the
# 11486  advertisement             song  False  The TV commercial promoted the
# 11487  advertisement             song  False  The TV commercial promoted the
# 11488            bad             song  False  The TV commercial promoted the
# 11489           beer             song  False  The TV commercial promoted the
# 11490           beer             song  False  The TV commercial promoted the
# 11491         cereal             song  False  The TV commercial promoted the
# 11492           chip             song  False  The TV commercial promoted the
# 11493        cleaner             song  False  The TV commercial promoted the
# 11494     discussion             song  False  The TV commercial promoted the
# 11495           drug             song  False  The TV commercial promoted the
# 11496          event             song  False  The TV commercial promoted the
# 11497           food             song  False  The TV commercial promoted the
# 11498           food             song  False  The TV commercial promoted the
# 11499           game             song  False  The TV commercial promoted the
# 11500        product             song  False  The TV commercial promoted the
# 11501        product             song  False  The TV commercial promoted the
# 11502        product             song  False  The TV commercial promoted the
# 11503        product             song  False  The TV commercial promoted the
# 11504        product             song  False  The TV commercial promoted the
# 11505        product             song  False  The TV commercial promoted the
# 11506        product             song  False  The TV commercial promoted the
# 11507        product             song  False  The TV commercial promoted the
# 11508        product             song  False  The TV commercial promoted the
# 11509        product             song  False  The TV commercial promoted the
# 11510       response             song  False  The TV commercial promoted the
# 11511           shoe             song  False  The TV commercial promoted the
# 11512     sport game             song  False  The TV commercial promoted the
# 11513          store             song  False  The TV commercial promoted the
# 11514          story             song  False  The TV commercial promoted the
# 11515        student             song  False  The TV commercial promoted the
# 11516         viewer             song  False  The TV commercial promoted the
# 11517            war             song  False  The TV commercial promoted the
#
#
# The abstract painting confused the
#            Resp Predicted Tokens   isin                             Sentence
# 5225     artist         painting  False  The abstract painting confused the
# 5226     artist         painting  False  The abstract painting confused the
# 5227     artist         painting  False  The abstract painting confused the
# 5228     artist         painting  False  The abstract painting confused the
# 5229   audience         painting  False  The abstract painting confused the
# 5230   audience         painting  False  The abstract painting confused the
# 5231      buyer         painting  False  The abstract painting confused the
# 5232      crowd         painting  False  The abstract painting confused the
# 5233   customer         painting  False  The abstract painting confused the
# 5234    gallery         painting  False  The abstract painting confused the
# 5235       girl         painting  False  The abstract painting confused the
# 5236        kid         painting  False  The abstract painting confused the
# 5237        man         painting  False  The abstract painting confused the
# 5238   onlooker         painting  False  The abstract painting confused the
# 5239   onlooker         painting  False  The abstract painting confused the
# 5240     person         painting  False  The abstract painting confused the
# 5241     person         painting  False  The abstract painting confused the
# 5242     person         painting  False  The abstract painting confused the
# 5243     person         painting  False  The abstract painting confused the
# 5244     person         painting  False  The abstract painting confused the
# 5245     person         painting  False  The abstract painting confused the
# 5246     person         painting  False  The abstract painting confused the
# 5247  spectator         painting  False  The abstract painting confused the
# 5248    student         painting  False  The abstract painting confused the
# 5249    student         painting  False  The abstract painting confused the
# 5250     viewer         painting  False  The abstract painting confused the
# 5251     viewer         painting  False  The abstract painting confused the
# 5252     viewer         painting  False  The abstract painting confused the
# 5253     viewer         painting  False  The abstract painting confused the
# 5254     viewer         painting  False  The abstract painting confused the
# 5255     viewer         painting  False  The abstract painting confused the
# 5256     viewer         painting  False  The abstract painting confused the
# 5257     viewer         painting  False  The abstract painting confused the
#
#
# The acclaimed writer explained the
#              Resp Predicted Tokens   isin                             Sentence
# 5258         book        following  False  The acclaimed writer explained the
# 5259         book        following  False  The acclaimed writer explained the
# 5260         book        following  False  The acclaimed writer explained the
# 5261         book        following  False  The acclaimed writer explained the
# 5262       detail        following  False  The acclaimed writer explained the
# 5263   experiment        following  False  The acclaimed writer explained the
# 5264         goal        following  False  The acclaimed writer explained the
# 5265  inspiration        following  False  The acclaimed writer explained the
# 5266        issue        following  False  The acclaimed writer explained the
# 5267       lesson        following  False  The acclaimed writer explained the
# 5268         life        following  False  The acclaimed writer explained the
# 5269         news        following  False  The acclaimed writer explained the
# 5270        novel        following  False  The acclaimed writer explained the
# 5271        novel        following  False  The acclaimed writer explained the
# 5272        novel        following  False  The acclaimed writer explained the
# 5273        novel        following  False  The acclaimed writer explained the
# 5274        novel        following  False  The acclaimed writer explained the
# 5275        novel        following  False  The acclaimed writer explained the
# 5276         plot        following  False  The acclaimed writer explained the
# 5277         plot        following  False  The acclaimed writer explained the
# 5278         plot        following  False  The acclaimed writer explained the
# 5279         plot        following  False  The acclaimed writer explained the
# 5280    procedure        following  False  The acclaimed writer explained the
# 5281        story        following  False  The acclaimed writer explained the
# 5282        story        following  False  The acclaimed writer explained the
# 5283        story        following  False  The acclaimed writer explained the
# 5284        story        following  False  The acclaimed writer explained the
# 5285        story        following  False  The acclaimed writer explained the
# 5286        story        following  False  The acclaimed writer explained the
# 5287        story        following  False  The acclaimed writer explained the
# 5288        story        following  False  The acclaimed writer explained the
# 5289        story        following  False  The acclaimed writer explained the
# 5290        story        following  False  The acclaimed writer explained the
# 5291        story        following  False  The acclaimed writer explained the
# 5292        story        following  False  The acclaimed writer explained the
#
#
# The ailing team forfeited the
#      Resp Predicted Tokens   isin                        Sentence
# 0   fight            title  False  The ailing team forfeited the
# 1    game            title  False  The ailing team forfeited the
# 2    game            title  False  The ailing team forfeited the
# 3    game            title  False  The ailing team forfeited the
# 4    game            title  False  The ailing team forfeited the
# 5    game            title  False  The ailing team forfeited the
# 6    game            title  False  The ailing team forfeited the
# 7    game            title  False  The ailing team forfeited the
# 8    game            title  False  The ailing team forfeited the
# 9    game            title  False  The ailing team forfeited the
# 10   game            title  False  The ailing team forfeited the
# 11   game            title  False  The ailing team forfeited the
# 12   game            title  False  The ailing team forfeited the
# 13   game            title  False  The ailing team forfeited the
# 14   game            title  False  The ailing team forfeited the
# 15   game            title  False  The ailing team forfeited the
# 16   game            title  False  The ailing team forfeited the
# 17   game            title  False  The ailing team forfeited the
# 18   game            title  False  The ailing team forfeited the
# 19   game            title  False  The ailing team forfeited the
# 20  match            title  False  The ailing team forfeited the
# 21  match            title  False  The ailing team forfeited the
# 22  match            title  False  The ailing team forfeited the
# 23  match            title  False  The ailing team forfeited the
# 24  match            title  False  The ailing team forfeited the
# 25  match            title  False  The ailing team forfeited the
# 26  match            title  False  The ailing team forfeited the
# 27  match            title  False  The ailing team forfeited the
# 28  match            title  False  The ailing team forfeited the
# 29  medal            title  False  The ailing team forfeited the
# 30   team            title  False  The ailing team forfeited the
#
#
# The amateur photographer snapped some
#           Resp Predicted Tokens   isin                                Sentence
# 31       photo                .  False  The amateur photographer snapped some
# 32       photo                .  False  The amateur photographer snapped some
# 33       photo                .  False  The amateur photographer snapped some
# 34       photo                .  False  The amateur photographer snapped some
# 35       photo                .  False  The amateur photographer snapped some
# 36       photo                .  False  The amateur photographer snapped some
# 37       photo                .  False  The amateur photographer snapped some
# 38       photo                .  False  The amateur photographer snapped some
# 39       photo                .  False  The amateur photographer snapped some
# 40       photo                .  False  The amateur photographer snapped some
# 41       photo                .  False  The amateur photographer snapped some
# 42       photo                .  False  The amateur photographer snapped some
# 43       photo                .  False  The amateur photographer snapped some
# 44       photo                .  False  The amateur photographer snapped some
# 45       photo                .  False  The amateur photographer snapped some
# 46  photograph                .  False  The amateur photographer snapped some
# 47  photograph                .  False  The amateur photographer snapped some
# 48  photograph                .  False  The amateur photographer snapped some
# 49     picture                .  False  The amateur photographer snapped some
# 50     picture                .  False  The amateur photographer snapped some
# 51     picture                .  False  The amateur photographer snapped some
# 52     picture                .  False  The amateur photographer snapped some
# 53     picture                .  False  The amateur photographer snapped some
# 54     picture                .  False  The amateur photographer snapped some
# 55     picture                .  False  The amateur photographer snapped some
# 56     picture                .  False  The amateur photographer snapped some
# 57     picture                .  False  The amateur photographer snapped some
# 58     picture                .  False  The amateur photographer snapped some
# 59     picture                .  False  The amateur photographer snapped some
# 60     picture                .  False  The amateur photographer snapped some
# 61     picture                .  False  The amateur photographer snapped some
# 62     picture                .  False  The amateur photographer snapped some
# 63     picture                .  False  The amateur photographer snapped some
# 64     picture                .  False  The amateur photographer snapped some
# 65     picture                .  False  The amateur photographer snapped some
# 66     picture                .  False  The amateur photographer snapped some
# 67     picture                .  False  The amateur photographer snapped some
# 68        shot                .  False  The amateur photographer snapped some
# 69        shot                .  False  The amateur photographer snapped some
#
#
# The amazing astronaut orbited the
#           Resp Predicted Tokens   isin                            Sentence
# 70  atmosphere             moon  False  The amazing astronaut orbited the
# 71       earth             moon  False  The amazing astronaut orbited the
# 72       earth             moon  False  The amazing astronaut orbited the
# 73       earth             moon  False  The amazing astronaut orbited the
# 74       earth             moon  False  The amazing astronaut orbited the
# 75       earth             moon  False  The amazing astronaut orbited the
# 76       earth             moon  False  The amazing astronaut orbited the
# 77       earth             moon  False  The amazing astronaut orbited the
# 78      galaxy             moon  False  The amazing astronaut orbited the
# 79       globe             moon  False  The amazing astronaut orbited the
# 80        moon             moon   True  The amazing astronaut orbited the
# 81        moon             moon   True  The amazing astronaut orbited the
# 82        moon             moon   True  The amazing astronaut orbited the
# 83        moon             moon   True  The amazing astronaut orbited the
# 84        moon             moon   True  The amazing astronaut orbited the
# 85        moon             moon   True  The amazing astronaut orbited the
# 86        moon             moon   True  The amazing astronaut orbited the
# 87        moon             moon   True  The amazing astronaut orbited the
# 88        moon             moon   True  The amazing astronaut orbited the
# 89        moon             moon   True  The amazing astronaut orbited the
# 90        moon             moon   True  The amazing astronaut orbited the
# 91      planet             moon  False  The amazing astronaut orbited the
# 92      rocket             moon  False  The amazing astronaut orbited the
# 93        ship             moon  False  The amazing astronaut orbited the
# 94       space             moon  False  The amazing astronaut orbited the
# 95    universe             moon  False  The amazing astronaut orbited the
# 96       world             moon  False  The amazing astronaut orbited the
# 97       world             moon  False  The amazing astronaut orbited the
#
#
# The angry mother scolded the
#          Resp Predicted Tokens   isin                       Sentence
# 98       baby           abbess  False  The angry mother scolded the
# 99        boy           abbess  False  The angry mother scolded the
# 100       boy           abbess  False  The angry mother scolded the
# 101       boy           abbess  False  The angry mother scolded the
# 102       boy           abbess  False  The angry mother scolded the
# 103     child           abbess  False  The angry mother scolded the
# 104     child           abbess  False  The angry mother scolded the
# 105     child           abbess  False  The angry mother scolded the
# 106     child           abbess  False  The angry mother scolded the
# 107     child           abbess  False  The angry mother scolded the
# 108     child           abbess  False  The angry mother scolded the
# 109     child           abbess  False  The angry mother scolded the
# 110     child           abbess  False  The angry mother scolded the
# 111     child           abbess  False  The angry mother scolded the
# 112     child           abbess  False  The angry mother scolded the
# 113     child           abbess  False  The angry mother scolded the
# 114     child           abbess  False  The angry mother scolded the
# 115     child           abbess  False  The angry mother scolded the
# 116     child           abbess  False  The angry mother scolded the
# 117     child           abbess  False  The angry mother scolded the
# 118     child           abbess  False  The angry mother scolded the
# 119     child           abbess  False  The angry mother scolded the
# 120     child           abbess  False  The angry mother scolded the
# 121     child           abbess  False  The angry mother scolded the
# 122     child           abbess  False  The angry mother scolded the
# 123     child           abbess  False  The angry mother scolded the
# 124     child           abbess  False  The angry mother scolded the
# 125     child           abbess  False  The angry mother scolded the
# 126     child           abbess  False  The angry mother scolded the
# 127     child           abbess  False  The angry mother scolded the
# 128     child           abbess  False  The angry mother scolded the
# 129     child           abbess  False  The angry mother scolded the
# 130  daughter           abbess  False  The angry mother scolded the
# 131       dog           abbess  False  The angry mother scolded the
# 132       kid           abbess  False  The angry mother scolded the
# 133       kid           abbess  False  The angry mother scolded the
# 134       son           abbess  False  The angry mother scolded the
#
#
# The angry mother took his
#             Resp Predicted Tokens   isin                    Sentence
# 5293   allowance                .  False  The angry mother took his
# 5294         car                .  False  The angry mother took his
# 5295         car                .  False  The angry mother took his
# 5296         car                .  False  The angry mother took his
# 5297       chair                .  False  The angry mother took his
# 5298       child                .  False  The angry mother took his
# 5299        coat                .  False  The angry mother took his
# 5300    computer                .  False  The angry mother took his
# 5301        game                .  False  The angry mother took his
# 5302        game                .  False  The angry mother took his
# 5303        game                .  False  The angry mother took his
# 5304    homework                .  False  The angry mother took his
# 5305         key                .  False  The angry mother took his
# 5306         key                .  False  The angry mother took his
# 5307       money                .  False  The angry mother took his
# 5308       phone                .  False  The angry mother took his
# 5309       phone                .  False  The angry mother took his
# 5310       phone                .  False  The angry mother took his
# 5311       phone                .  False  The angry mother took his
# 5312       phone                .  False  The angry mother took his
# 5313  punishment                .  False  The angry mother took his
# 5314         son                .  False  The angry mother took his
# 5315         son                .  False  The angry mother took his
# 5316        time                .  False  The angry mother took his
# 5317         toy                .  False  The angry mother took his
# 5318         toy                .  False  The angry mother took his
# 5319         toy                .  False  The angry mother took his
# 5320         toy                .  False  The angry mother took his
# 5321         toy                .  False  The angry mother took his
# 5322         toy                .  False  The angry mother took his
# 5323         toy                .  False  The angry mother took his
# 5324         toy                .  False  The angry mother took his
# 5325         toy                .  False  The angry mother took his
# 5326         toy                .  False  The angry mother took his
# 5327         toy                .  False  The angry mother took his
# 5328         toy                .  False  The angry mother took his
#
#
# The annoying roommate borrowed the
#             Resp Predicted Tokens   isin                             Sentence
# 5329        bike                .  False  The annoying roommate borrowed the
# 5330        book                .  False  The annoying roommate borrowed the
# 5331        book                .  False  The annoying roommate borrowed the
# 5332        book                .  False  The annoying roommate borrowed the
# 5333       broom                .  False  The annoying roommate borrowed the
# 5334       broom                .  False  The annoying roommate borrowed the
# 5335  calculator                .  False  The annoying roommate borrowed the
# 5336         car                .  False  The annoying roommate borrowed the
# 5337     clothes                .  False  The annoying roommate borrowed the
# 5338     clothes                .  False  The annoying roommate borrowed the
# 5339     clothes                .  False  The annoying roommate borrowed the
# 5340     clothes                .  False  The annoying roommate borrowed the
# 5341     clothes                .  False  The annoying roommate borrowed the
# 5342     clothes                .  False  The annoying roommate borrowed the
# 5343     clothes                .  False  The annoying roommate borrowed the
# 5344     clothes                .  False  The annoying roommate borrowed the
# 5345     clothes                .  False  The annoying roommate borrowed the
# 5346     clothes                .  False  The annoying roommate borrowed the
# 5347    clothing                .  False  The annoying roommate borrowed the
# 5348    computer                .  False  The annoying roommate borrowed the
# 5349       dress                .  False  The annoying roommate borrowed the
# 5350        food                .  False  The annoying roommate borrowed the
# 5351        food                .  False  The annoying roommate borrowed the
# 5352      guitar                .  False  The annoying roommate borrowed the
# 5353   hairbrush                .  False  The annoying roommate borrowed the
# 5354  headphones                .  False  The annoying roommate borrowed the
# 5355        iron                .  False  The annoying roommate borrowed the
# 5356      pencil                .  False  The annoying roommate borrowed the
# 5357       phone                .  False  The annoying roommate borrowed the
# 5358     shampoo                .  False  The annoying roommate borrowed the
# 5359       shirt                .  False  The annoying roommate borrowed the
# 5360       shirt                .  False  The annoying roommate borrowed the
# 5361     toaster                .  False  The annoying roommate borrowed the
# 5362  toothpaste                .  False  The annoying roommate borrowed the
#
#
# The artisanal baker kneaded some
#       Resp Predicted Tokens   isin                           Sentence
# 135  bread                .  False  The artisanal baker kneaded some
# 136  bread                .  False  The artisanal baker kneaded some
# 137  bread                .  False  The artisanal baker kneaded some
# 138  bread                .  False  The artisanal baker kneaded some
# 139  bread                .  False  The artisanal baker kneaded some
# 140  bread                .  False  The artisanal baker kneaded some
# 141  bread                .  False  The artisanal baker kneaded some
# 142  bread                .  False  The artisanal baker kneaded some
# 143  bread                .  False  The artisanal baker kneaded some
# 144  bread                .  False  The artisanal baker kneaded some
# 145  bread                .  False  The artisanal baker kneaded some
# 146  bread                .  False  The artisanal baker kneaded some
# 147  bread                .  False  The artisanal baker kneaded some
# 148  bread                .  False  The artisanal baker kneaded some
# 149  dough                .  False  The artisanal baker kneaded some
# 150  dough                .  False  The artisanal baker kneaded some
# 151  dough                .  False  The artisanal baker kneaded some
# 152  dough                .  False  The artisanal baker kneaded some
# 153  dough                .  False  The artisanal baker kneaded some
# 154  dough                .  False  The artisanal baker kneaded some
# 155  dough                .  False  The artisanal baker kneaded some
# 156  dough                .  False  The artisanal baker kneaded some
# 157  dough                .  False  The artisanal baker kneaded some
# 158  dough                .  False  The artisanal baker kneaded some
# 159  dough                .  False  The artisanal baker kneaded some
# 160  dough                .  False  The artisanal baker kneaded some
# 161  dough                .  False  The artisanal baker kneaded some
# 162  dough                .  False  The artisanal baker kneaded some
# 163  dough                .  False  The artisanal baker kneaded some
# 164  dough                .  False  The artisanal baker kneaded some
# 165  dough                .  False  The artisanal baker kneaded some
# 166  dough                .  False  The artisanal baker kneaded some
# 167  dough                .  False  The artisanal baker kneaded some
# 168  dough                .  False  The artisanal baker kneaded some
# 169  flour                .  False  The artisanal baker kneaded some
# 170  flour                .  False  The artisanal baker kneaded some
# 171  water                .  False  The artisanal baker kneaded some
#
#
# The aspiring comedian told the
#          Resp Predicted Tokens   isin                         Sentence
# 172  audience        following  False  The aspiring comedian told the
# 173      joke        following  False  The aspiring comedian told the
# 174      joke        following  False  The aspiring comedian told the
# 175      joke        following  False  The aspiring comedian told the
# 176      joke        following  False  The aspiring comedian told the
# 177      joke        following  False  The aspiring comedian told the
# 178      joke        following  False  The aspiring comedian told the
# 179      joke        following  False  The aspiring comedian told the
# 180      joke        following  False  The aspiring comedian told the
# 181      joke        following  False  The aspiring comedian told the
# 182      joke        following  False  The aspiring comedian told the
# 183      joke        following  False  The aspiring comedian told the
# 184      joke        following  False  The aspiring comedian told the
# 185      joke        following  False  The aspiring comedian told the
# 186      joke        following  False  The aspiring comedian told the
# 187      joke        following  False  The aspiring comedian told the
# 188      joke        following  False  The aspiring comedian told the
# 189      joke        following  False  The aspiring comedian told the
# 190      joke        following  False  The aspiring comedian told the
# 191      joke        following  False  The aspiring comedian told the
# 192      joke        following  False  The aspiring comedian told the
# 193      joke        following  False  The aspiring comedian told the
# 194      joke        following  False  The aspiring comedian told the
# 195      joke        following  False  The aspiring comedian told the
# 196      joke        following  False  The aspiring comedian told the
# 197      joke        following  False  The aspiring comedian told the
# 198      joke        following  False  The aspiring comedian told the
# 199      joke        following  False  The aspiring comedian told the
# 200      joke        following  False  The aspiring comedian told the
# 201      joke        following  False  The aspiring comedian told the
# 202      joke        following  False  The aspiring comedian told the
# 203      joke        following  False  The aspiring comedian told the
# 204     story        following  False  The aspiring comedian told the
# 205     story        following  False  The aspiring comedian told the
# 206     story        following  False  The aspiring comedian told the
# 207     story        following  False  The aspiring comedian told the
# 208      tale        following  False  The aspiring comedian told the
#
#
# The assistant manager replaced the
#              Resp Predicted Tokens   isin                             Sentence
# 5363    assistant                .  False  The assistant manager replaced the
# 5364         book                .  False  The assistant manager replaced the
# 5365         boss                .  False  The assistant manager replaced the
# 5366         bowl                .  False  The assistant manager replaced the
# 5367         card                .  False  The assistant manager replaced the
# 5368        chair                .  False  The assistant manager replaced the
# 5369    colleague                .  False  The assistant manager replaced the
# 5370     coworker                .  False  The assistant manager replaced the
# 5371         door                .  False  The assistant manager replaced the
# 5372     employee                .  False  The assistant manager replaced the
# 5373     employee                .  False  The assistant manager replaced the
# 5374     employee                .  False  The assistant manager replaced the
# 5375         item                .  False  The assistant manager replaced the
# 5376         item                .  False  The assistant manager replaced the
# 5377    lightbulb                .  False  The assistant manager replaced the
# 5378      manager                .  False  The assistant manager replaced the
# 5379      manager                .  False  The assistant manager replaced the
# 5380      manager                .  False  The assistant manager replaced the
# 5381      manager                .  False  The assistant manager replaced the
# 5382      manager                .  False  The assistant manager replaced the
# 5383      manager                .  False  The assistant manager replaced the
# 5384         menu                .  False  The assistant manager replaced the
# 5385  merchandise                .  False  The assistant manager replaced the
# 5386      old one                .  False  The assistant manager replaced the
# 5387        paper                .  False  The assistant manager replaced the
# 5388          pen                .  False  The assistant manager replaced the
# 5389        phone                .  False  The assistant manager replaced the
# 5390    secretary                .  False  The assistant manager replaced the
# 5391      stapler                .  False  The assistant manager replaced the
# 5392        water                .  False  The assistant manager replaced the
# 5393       worker                .  False  The assistant manager replaced the
#
#
# The auto mechanic fixed the
#            Resp Predicted Tokens   isin                      Sentence
# 209     bicycle          gearbox  False  The auto mechanic fixed the
# 210         car          gearbox  False  The auto mechanic fixed the
# 211         car          gearbox  False  The auto mechanic fixed the
# 212         car          gearbox  False  The auto mechanic fixed the
# 213         car          gearbox  False  The auto mechanic fixed the
# 214         car          gearbox  False  The auto mechanic fixed the
# 215         car          gearbox  False  The auto mechanic fixed the
# 216         car          gearbox  False  The auto mechanic fixed the
# 217         car          gearbox  False  The auto mechanic fixed the
# 218         car          gearbox  False  The auto mechanic fixed the
# 219         car          gearbox  False  The auto mechanic fixed the
# 220         car          gearbox  False  The auto mechanic fixed the
# 221         car          gearbox  False  The auto mechanic fixed the
# 222         car          gearbox  False  The auto mechanic fixed the
# 223         car          gearbox  False  The auto mechanic fixed the
# 224         car          gearbox  False  The auto mechanic fixed the
# 225         car          gearbox  False  The auto mechanic fixed the
# 226         car          gearbox  False  The auto mechanic fixed the
# 227         car          gearbox  False  The auto mechanic fixed the
# 228         car          gearbox  False  The auto mechanic fixed the
# 229         car          gearbox  False  The auto mechanic fixed the
# 230         car          gearbox  False  The auto mechanic fixed the
# 231         car          gearbox  False  The auto mechanic fixed the
# 232         car          gearbox  False  The auto mechanic fixed the
# 233         car          gearbox  False  The auto mechanic fixed the
# 234         car          gearbox  False  The auto mechanic fixed the
# 235         car          gearbox  False  The auto mechanic fixed the
# 236         car          gearbox  False  The auto mechanic fixed the
# 237         car          gearbox  False  The auto mechanic fixed the
# 238         car          gearbox  False  The auto mechanic fixed the
# 239         car          gearbox  False  The auto mechanic fixed the
# 240         car          gearbox  False  The auto mechanic fixed the
# 241         car          gearbox  False  The auto mechanic fixed the
# 242         car          gearbox  False  The auto mechanic fixed the
# 243         car          gearbox  False  The auto mechanic fixed the
# 244     problem          gearbox  False  The auto mechanic fixed the
# 245  spark plug          gearbox  False  The auto mechanic fixed the
# 246        tire          gearbox  False  The auto mechanic fixed the
# 247       truck          gearbox  False  The auto mechanic fixed the
#
#
# The autumn leaves changed their
#       Resp Predicted Tokens   isin                          Sentence
# 248  color            shape  False  The autumn leaves changed their
# 249  color            shape  False  The autumn leaves changed their
# 250  color            shape  False  The autumn leaves changed their
# 251  color            shape  False  The autumn leaves changed their
# 252  color            shape  False  The autumn leaves changed their
# 253  color            shape  False  The autumn leaves changed their
# 254  color            shape  False  The autumn leaves changed their
# 255  color            shape  False  The autumn leaves changed their
# 256  color            shape  False  The autumn leaves changed their
# 257  color            shape  False  The autumn leaves changed their
# 258  color            shape  False  The autumn leaves changed their
# 259  color            shape  False  The autumn leaves changed their
# 260  color            shape  False  The autumn leaves changed their
# 261  color            shape  False  The autumn leaves changed their
# 262  color            shape  False  The autumn leaves changed their
# 263  color            shape  False  The autumn leaves changed their
# 264  color            shape  False  The autumn leaves changed their
# 265  color            shape  False  The autumn leaves changed their
# 266  color            shape  False  The autumn leaves changed their
# 267  color            shape  False  The autumn leaves changed their
# 268  color            shape  False  The autumn leaves changed their
# 269  color            shape  False  The autumn leaves changed their
# 270  color            shape  False  The autumn leaves changed their
# 271  color            shape  False  The autumn leaves changed their
# 272  color            shape  False  The autumn leaves changed their
# 273  color            shape  False  The autumn leaves changed their
# 274  color            shape  False  The autumn leaves changed their
# 275  color            shape  False  The autumn leaves changed their
# 276  color            shape  False  The autumn leaves changed their
# 277  color            shape  False  The autumn leaves changed their
# 278  color            shape  False  The autumn leaves changed their
# 279  color            shape  False  The autumn leaves changed their
# 280  color            shape  False  The autumn leaves changed their
# 281  color            shape  False  The autumn leaves changed their
# 282  color            shape  False  The autumn leaves changed their
# 283   mind            shape  False  The autumn leaves changed their
# 284   mood            shape  False  The autumn leaves changed their
# 285   mood            shape  False  The autumn leaves changed their
#
#
# The avid hikers climbed the
#          Resp Predicted Tokens   isin                      Sentence
# 286      hill         mountain  False  The avid hikers climbed the
# 287      hill         mountain  False  The avid hikers climbed the
# 288  mountain         mountain   True  The avid hikers climbed the
# 289  mountain         mountain   True  The avid hikers climbed the
# 290  mountain         mountain   True  The avid hikers climbed the
# 291  mountain         mountain   True  The avid hikers climbed the
# 292  mountain         mountain   True  The avid hikers climbed the
# 293  mountain         mountain   True  The avid hikers climbed the
# 294  mountain         mountain   True  The avid hikers climbed the
# 295  mountain         mountain   True  The avid hikers climbed the
# 296  mountain         mountain   True  The avid hikers climbed the
# 297  mountain         mountain   True  The avid hikers climbed the
# 298  mountain         mountain   True  The avid hikers climbed the
# 299  mountain         mountain   True  The avid hikers climbed the
# 300  mountain         mountain   True  The avid hikers climbed the
# 301  mountain         mountain   True  The avid hikers climbed the
# 302  mountain         mountain   True  The avid hikers climbed the
# 303  mountain         mountain   True  The avid hikers climbed the
# 304  mountain         mountain   True  The avid hikers climbed the
# 305  mountain         mountain   True  The avid hikers climbed the
# 306  mountain         mountain   True  The avid hikers climbed the
# 307  mountain         mountain   True  The avid hikers climbed the
# 308  mountain         mountain   True  The avid hikers climbed the
# 309  mountain         mountain   True  The avid hikers climbed the
# 310  mountain         mountain   True  The avid hikers climbed the
# 311  mountain         mountain   True  The avid hikers climbed the
# 312  mountain         mountain   True  The avid hikers climbed the
# 313  mountain         mountain   True  The avid hikers climbed the
# 314  mountain         mountain   True  The avid hikers climbed the
# 315  mountain         mountain   True  The avid hikers climbed the
# 316  mountain         mountain   True  The avid hikers climbed the
# 317  mountain         mountain   True  The avid hikers climbed the
# 318  mountain         mountain   True  The avid hikers climbed the
# 319  mountain         mountain   True  The avid hikers climbed the
# 320  mountain         mountain   True  The avid hikers climbed the
# 321      rock         mountain  False  The avid hikers climbed the
# 322     trail         mountain  False  The avid hikers climbed the
# 323      tree         mountain  False  The avid hikers climbed the
#
#
# The bad teen graffitied the
#             Resp Predicted Tokens   isin                      Sentence
# 5394      bridge             wall  False  The bad teen graffitied the
# 5395    building             wall  False  The bad teen graffitied the
# 5396    building             wall  False  The bad teen graffitied the
# 5397        drug             wall  False  The bad teen graffitied the
# 5398  everything             wall  False  The bad teen graffitied the
# 5399      friend             wall  False  The bad teen graffitied the
# 5400    good kid             wall  False  The bad teen graffitied the
# 5401      parent             wall  False  The bad teen graffitied the
# 5402      person             wall  False  The bad teen graffitied the
# 5403      puzzle             wall  False  The bad teen graffitied the
# 5404      school             wall  False  The bad teen graffitied the
# 5405    sidewalk             wall  False  The bad teen graffitied the
# 5406   situation             wall  False  The bad teen graffitied the
# 5407       store             wall  False  The bad teen graffitied the
# 5408   train car             wall  False  The bad teen graffitied the
# 5409        wall             wall   True  The bad teen graffitied the
# 5410        wall             wall   True  The bad teen graffitied the
# 5411        wall             wall   True  The bad teen graffitied the
# 5412        wall             wall   True  The bad teen graffitied the
# 5413        wall             wall   True  The bad teen graffitied the
# 5414        wall             wall   True  The bad teen graffitied the
# 5415        wall             wall   True  The bad teen graffitied the
# 5416        wall             wall   True  The bad teen graffitied the
# 5417        wall             wall   True  The bad teen graffitied the
# 5418        wall             wall   True  The bad teen graffitied the
# 5419        wall             wall   True  The bad teen graffitied the
# 5420        wall             wall   True  The bad teen graffitied the
# 5421        wall             wall   True  The bad teen graffitied the
# 5422        wall             wall   True  The bad teen graffitied the
# 5423        wall             wall   True  The bad teen graffitied the
# 5424        wall             wall   True  The bad teen graffitied the
# 5425        wall             wall   True  The bad teen graffitied the
# 5426        wall             wall   True  The bad teen graffitied the
# 5427        wall             wall   True  The bad teen graffitied the
# 5428        wall             wall   True  The bad teen graffitied the
#
#
# The barefoot man stubbed his
#       Resp Predicted Tokens   isin                       Sentence
# 324   foot                .  False  The barefoot man stubbed his
# 325   foot                .  False  The barefoot man stubbed his
# 326   foot                .  False  The barefoot man stubbed his
# 327   foot                .  False  The barefoot man stubbed his
# 328  pinky                .  False  The barefoot man stubbed his
# 329    toe                .  False  The barefoot man stubbed his
# 330    toe                .  False  The barefoot man stubbed his
# 331    toe                .  False  The barefoot man stubbed his
# 332    toe                .  False  The barefoot man stubbed his
# 333    toe                .  False  The barefoot man stubbed his
# 334    toe                .  False  The barefoot man stubbed his
# 335    toe                .  False  The barefoot man stubbed his
# 336    toe                .  False  The barefoot man stubbed his
# 337    toe                .  False  The barefoot man stubbed his
# 338    toe                .  False  The barefoot man stubbed his
# 339    toe                .  False  The barefoot man stubbed his
# 340    toe                .  False  The barefoot man stubbed his
# 341    toe                .  False  The barefoot man stubbed his
# 342    toe                .  False  The barefoot man stubbed his
# 343    toe                .  False  The barefoot man stubbed his
# 344    toe                .  False  The barefoot man stubbed his
# 345    toe                .  False  The barefoot man stubbed his
# 346    toe                .  False  The barefoot man stubbed his
# 347    toe                .  False  The barefoot man stubbed his
# 348    toe                .  False  The barefoot man stubbed his
# 349    toe                .  False  The barefoot man stubbed his
# 350    toe                .  False  The barefoot man stubbed his
# 351    toe                .  False  The barefoot man stubbed his
# 352    toe                .  False  The barefoot man stubbed his
# 353    toe                .  False  The barefoot man stubbed his
# 354    toe                .  False  The barefoot man stubbed his
# 355    toe                .  False  The barefoot man stubbed his
# 356    toe                .  False  The barefoot man stubbed his
# 357    toe                .  False  The barefoot man stubbed his
# 358    toe                .  False  The barefoot man stubbed his
# 359    toe                .  False  The barefoot man stubbed his
# 360    toe                .  False  The barefoot man stubbed his
# 361    toe                .  False  The barefoot man stubbed his
# 362    toe                .  False  The barefoot man stubbed his
#
#
# The baseball player swung his
#     Resp Predicted Tokens  isin                        Sentence
# 363  bat              bat  True  The baseball player swung his
# 364  bat              bat  True  The baseball player swung his
# 365  bat              bat  True  The baseball player swung his
# 366  bat              bat  True  The baseball player swung his
# 367  bat              bat  True  The baseball player swung his
# 368  bat              bat  True  The baseball player swung his
# 369  bat              bat  True  The baseball player swung his
# 370  bat              bat  True  The baseball player swung his
# 371  bat              bat  True  The baseball player swung his
# 372  bat              bat  True  The baseball player swung his
# 373  bat              bat  True  The baseball player swung his
# 374  bat              bat  True  The baseball player swung his
# 375  bat              bat  True  The baseball player swung his
# 376  bat              bat  True  The baseball player swung his
# 377  bat              bat  True  The baseball player swung his
# 378  bat              bat  True  The baseball player swung his
# 379  bat              bat  True  The baseball player swung his
# 380  bat              bat  True  The baseball player swung his
# 381  bat              bat  True  The baseball player swung his
# 382  bat              bat  True  The baseball player swung his
# 383  bat              bat  True  The baseball player swung his
# 384  bat              bat  True  The baseball player swung his
# 385  bat              bat  True  The baseball player swung his
# 386  bat              bat  True  The baseball player swung his
# 387  bat              bat  True  The baseball player swung his
# 388  bat              bat  True  The baseball player swung his
# 389  bat              bat  True  The baseball player swung his
# 390  bat              bat  True  The baseball player swung his
# 391  bat              bat  True  The baseball player swung his
# 392  bat              bat  True  The baseball player swung his
# 393  bat              bat  True  The baseball player swung his
# 394  bat              bat  True  The baseball player swung his
# 395  bat              bat  True  The baseball player swung his
# 396  bat              bat  True  The baseball player swung his
# 397  bat              bat  True  The baseball player swung his
# 398  bat              bat  True  The baseball player swung his
# 399  bat              bat  True  The baseball player swung his
# 400  bat              bat  True  The baseball player swung his
# ...
# 5119   sunlight                .  False  The wilting flowers needed some
# 5120      water                .  False  The wilting flowers needed some
# 5121      water                .  False  The wilting flowers needed some
# 5122      water                .  False  The wilting flowers needed some
# 5123      water                .  False  The wilting flowers needed some
# 5124      water                .  False  The wilting flowers needed some
# 5125      water                .  False  The wilting flowers needed some
# 5126      water                .  False  The wilting flowers needed some
# 5127      water                .  False  The wilting flowers needed some
# 5128      water                .  False  The wilting flowers needed some
# 5129      water                .  False  The wilting flowers needed some
# 5130      water                .  False  The wilting flowers needed some
# 5131      water                .  False  The wilting flowers needed some
# 5132      water                .  False  The wilting flowers needed some
# 5133      water                .  False  The wilting flowers needed some
# 5134      water                .  False  The wilting flowers needed some
# 5135      water                .  False  The wilting flowers needed some
# 5136      water                .  False  The wilting flowers needed some
# 5137      water                .  False  The wilting flowers needed some
# 5138      water                .  False  The wilting flowers needed some
# 5139      water                .  False  The wilting flowers needed some
# 5140      water                .  False  The wilting flowers needed some
# 5141      water                .  False  The wilting flowers needed some
# 5142      water                .  False  The wilting flowers needed some
# 5143      water                .  False  The wilting flowers needed some
# 5144      water                .  False  The wilting flowers needed some
# 5145      water                .  False  The wilting flowers needed some
# 5146      water                .  False  The wilting flowers needed some
# 5147      water                .  False  The wilting flowers needed some
# 5148      water                .  False  The wilting flowers needed some
# 5149      water                .  False  The wilting flowers needed some
# 5150      water                .  False  The wilting flowers needed some
# 5151      water                .  False  The wilting flowers needed some
# 5152      water                .  False  The wilting flowers needed some
#
#
# The wise man regaled his
#              Resp Predicted Tokens   isin                   Sentence
# 11938    audience          majesty  False  The wise man regaled his
# 11939        book          majesty  False  The wise man regaled his
# 11940        book          majesty  False  The wise man regaled his
# 11941        book          majesty  False  The wise man regaled his
# 11942        cane          majesty  False  The wise man regaled his
# 11943         car          majesty  False  The wise man regaled his
# 11944   childhood          majesty  False  The wise man regaled his
# 11945        diet          majesty  False  The wise man regaled his
# 11946         dog          majesty  False  The wise man regaled his
# 11947        fame          majesty  False  The wise man regaled his
# 11948     fortune          majesty  False  The wise man regaled his
# 11949      health          majesty  False  The wise man regaled his
# 11950       house          majesty  False  The wise man regaled his
# 11951      intake          majesty  False  The wise man regaled his
# 11952   knowledge          majesty  False  The wise man regaled his
# 11953        life          majesty  False  The wise man regaled his
# 11954        life          majesty  False  The wise man regaled his
# 11955    painting          majesty  False  The wise man regaled his
# 11956        past          majesty  False  The wise man regaled his
# 11957         pet          majesty  False  The wise man regaled his
# 11958       prize          majesty  False  The wise man regaled his
# 11959    question          majesty  False  The wise man regaled his
# 11960      secret          majesty  False  The wise man regaled his
# 11961         son          majesty  False  The wise man regaled his
# 11962  sweatshirt          majesty  False  The wise man regaled his
# 11963        tale          majesty  False  The wise man regaled his
# 11964     thought          majesty  False  The wise man regaled his
# 11965     thought          majesty  False  The wise man regaled his
# 11966     thought          majesty  False  The wise man regaled his
# 11967        wife          majesty  False  The wise man regaled his
# 11968      wisdom          majesty  False  The wise man regaled his
# 11969      wisdom          majesty  False  The wise man regaled his
#
#
# The wise mentor offered some
#              Resp Predicted Tokens   isin                       Sentence
# 5153       advice                .  False  The wise mentor offered some
# 5154       advice                .  False  The wise mentor offered some
# 5155       advice                .  False  The wise mentor offered some
# 5156       advice                .  False  The wise mentor offered some
# 5157       advice                .  False  The wise mentor offered some
# 5158       advice                .  False  The wise mentor offered some
# 5159       advice                .  False  The wise mentor offered some
# 5160       advice                .  False  The wise mentor offered some
# 5161       advice                .  False  The wise mentor offered some
# 5162       advice                .  False  The wise mentor offered some
# 5163       advice                .  False  The wise mentor offered some
# 5164       advice                .  False  The wise mentor offered some
# 5165       advice                .  False  The wise mentor offered some
# 5166       advice                .  False  The wise mentor offered some
# 5167       advice                .  False  The wise mentor offered some
# 5168       advice                .  False  The wise mentor offered some
# 5169       advice                .  False  The wise mentor offered some
# 5170       advice                .  False  The wise mentor offered some
# 5171       advice                .  False  The wise mentor offered some
# 5172       advice                .  False  The wise mentor offered some
# 5173       advice                .  False  The wise mentor offered some
# 5174       advice                .  False  The wise mentor offered some
# 5175       advice                .  False  The wise mentor offered some
# 5176       advice                .  False  The wise mentor offered some
# 5177       advice                .  False  The wise mentor offered some
# 5178       advice                .  False  The wise mentor offered some
# 5179       advice                .  False  The wise mentor offered some
# 5180       advice                .  False  The wise mentor offered some
# 5181       advice                .  False  The wise mentor offered some
# 5182       advice                .  False  The wise mentor offered some
# 5183       advice                .  False  The wise mentor offered some
# 5184       advice                .  False  The wise mentor offered some
# 5185  consolation                .  False  The wise mentor offered some
# 5186         help                .  False  The wise mentor offered some
# 5187         help                .  False  The wise mentor offered some
# 5188         help                .  False  The wise mentor offered some
# 5189         help                .  False  The wise mentor offered some
# 5190         help                .  False  The wise mentor offered some
# 5191       wisdom                .  False  The wise mentor offered some
#
#
# The wonderful artist shaped the
#             Resp Predicted Tokens   isin                          Sentence
# 11970       ball        landscape  False  The wonderful artist shaped the
# 11971       ball        landscape  False  The wonderful artist shaped the
# 11972       clay        landscape  False  The wonderful artist shaped the
# 11973       clay        landscape  False  The wonderful artist shaped the
# 11974       clay        landscape  False  The wonderful artist shaped the
# 11975       clay        landscape  False  The wonderful artist shaped the
# 11976       clay        landscape  False  The wonderful artist shaped the
# 11977       clay        landscape  False  The wonderful artist shaped the
# 11978       clay        landscape  False  The wonderful artist shaped the
# 11979       clay        landscape  False  The wonderful artist shaped the
# 11980       clay        landscape  False  The wonderful artist shaped the
# 11981       clay        landscape  False  The wonderful artist shaped the
# 11982      field        landscape  False  The wonderful artist shaped the
# 11983   painting        landscape  False  The wonderful artist shaped the
# 11984   painting        landscape  False  The wonderful artist shaped the
# 11985   painting        landscape  False  The wonderful artist shaped the
# 11986   painting        landscape  False  The wonderful artist shaped the
# 11987   painting        landscape  False  The wonderful artist shaped the
# 11988   painting        landscape  False  The wonderful artist shaped the
# 11989   painting        landscape  False  The wonderful artist shaped the
# 11990   painting        landscape  False  The wonderful artist shaped the
# 11991    picture        landscape  False  The wonderful artist shaped the
# 11992        pot        landscape  False  The wonderful artist shaped the
# 11993  sculpture        landscape  False  The wonderful artist shaped the
# 11994  sculpture        landscape  False  The wonderful artist shaped the
# 11995  sculpture        landscape  False  The wonderful artist shaped the
# 11996  sculpture        landscape  False  The wonderful artist shaped the
# 11997  sculpture        landscape  False  The wonderful artist shaped the
# 11998  sculpture        landscape  False  The wonderful artist shaped the
# 11999  sculpture        landscape  False  The wonderful artist shaped the
# 12000  sculpture        landscape  False  The wonderful artist shaped the
# 12001  sculpture        landscape  False  The wonderful artist shaped the
# 12002  sculpture        landscape  False  The wonderful artist shaped the
# 12003  sculpture        landscape  False  The wonderful artist shaped the
# 12004  sculpture        landscape  False  The wonderful artist shaped the
# 12005       wood        landscape  False  The wonderful artist shaped the
#
#
# The young landscaper mowed the
#        Resp Predicted Tokens   isin                         Sentence
# 5192  grass            grass   True  The young landscaper mowed the
# 5193   lawn            grass  False  The young landscaper mowed the
# 5194   lawn            grass  False  The young landscaper mowed the
# 5195   lawn            grass  False  The young landscaper mowed the
# 5196   lawn            grass  False  The young landscaper mowed the
# 5197   lawn            grass  False  The young landscaper mowed the
# 5198   lawn            grass  False  The young landscaper mowed the
# 5199   lawn            grass  False  The young landscaper mowed the
# 5200   lawn            grass  False  The young landscaper mowed the
# 5201   lawn            grass  False  The young landscaper mowed the
# 5202   lawn            grass  False  The young landscaper mowed the
# 5203   lawn            grass  False  The young landscaper mowed the
# 5204   lawn            grass  False  The young landscaper mowed the
# 5205   lawn            grass  False  The young landscaper mowed the
# 5206   lawn            grass  False  The young landscaper mowed the
# 5207   lawn            grass  False  The young landscaper mowed the
# 5208   lawn            grass  False  The young landscaper mowed the
# 5209   lawn            grass  False  The young landscaper mowed the
# 5210   lawn            grass  False  The young landscaper mowed the
# 5211   lawn            grass  False  The young landscaper mowed the
# 5212   lawn            grass  False  The young landscaper mowed the
# 5213   lawn            grass  False  The young landscaper mowed the
# 5214   lawn            grass  False  The young landscaper mowed the
# 5215   lawn            grass  False  The young landscaper mowed the
# 5216   lawn            grass  False  The young landscaper mowed the
# 5217   lawn            grass  False  The young landscaper mowed the
# 5218   lawn            grass  False  The young landscaper mowed the
# 5219   lawn            grass  False  The young landscaper mowed the
# 5220   lawn            grass  False  The young landscaper mowed the
# 5221   lawn            grass  False  The young landscaper mowed the
# 5222   lawn            grass  False  The young landscaper mowed the
# 5223   lawn            grass  False  The young landscaper mowed the
# 5224   yard            grass  False  The young landscaper mowed the
#
#
# The young student needed the
#                Resp Predicted Tokens   isin                       Sentence
# 12006        answer                .  False  The young student needed the
# 12007        answer                .  False  The young student needed the
# 12008        answer                .  False  The young student needed the
# 12009        answer                .  False  The young student needed the
# 12010        answer                .  False  The young student needed the
# 12011  answer sheet                .  False  The young student needed the
# 12012        asnwer                .  False  The young student needed the
# 12013     assistant                .  False  The young student needed the
# 12014          book                .  False  The young student needed the
# 12015          book                .  False  The young student needed the
# 12016          book                .  False  The young student needed the
# 12017    dictionary                .  False  The young student needed the
# 12018        eraser                .  False  The young student needed the
# 12019  extra credit                .  False  The young student needed the
# 12020  extra credit                .  False  The young student needed the
# 12021       glasses                .  False  The young student needed the
# 12022         grade                .  False  The young student needed the
# 12023         grade                .  False  The young student needed the
# 12024         grade                .  False  The young student needed the
# 12025         grade                .  False  The young student needed the
# 12026         grade                .  False  The young student needed the
# 12027         grade                .  False  The young student needed the
# 12028          help                .  False  The young student needed the
# 12029          help                .  False  The young student needed the
# 12030          help                .  False  The young student needed the
# 12031          help                .  False  The young student needed the
# 12032          help                .  False  The young student needed the
# 12033          help                .  False  The young student needed the
# 12034          help                .  False  The young student needed the
# 12035          help                .  False  The young student needed the
# 12036          help                .  False  The young student needed the
# 12037           job                .  False  The young student needed the
# 12038         money                .  False  The young student needed the
# 12039      notebook                .  False  The young student needed the
# 12040         paper                .  False  The young student needed the
# 12041         paper                .  False  The young student needed the
# 12042        pencil                .  False  The young student needed the
# 12043       proctor                .  False  The young student needed the
# 12044          time                .  False  The young student needed the
